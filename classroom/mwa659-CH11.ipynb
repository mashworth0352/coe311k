# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 1, 0, 1, 0, 1])

cs = CubicSpline(x, y, bc_type='natural')
x_interp = np.linspace(0, 5, 100)
y_interp = cs(x_interp)

degree = 3
coefficients = np.polyfit(x, y, degree)
polynomial = np.poly1d(coefficients)
y_poly = polynomial(x_interp)

plt.figure()
plt.scatter(x, y, label="Data points")
plt.plot(x_interp, y_interp, label="Cubic Spline")
plt.plot(x_interp, y_poly, label="Polynomial Fit (deg 3)")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Cubic Spline vs Polynomial Fit")
plt.legend()
plt.show()

#Comparison------------------------------------------------------------------------------------------------------

#While the polyfit method creates a smoother curve, the cublic spline method creates a function
#that includes the actual datapoints.This more effectively represents the trends of the data given.
