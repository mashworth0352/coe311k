# %%
import numpy as np
import matplotlib.pyplot as plt
x=2025
x2=2025
w=0
while (x2>=1):
    w=w+1
    x2=x2//2
y=np.zeros(w)
i=0
while (x >=1):
    if (x%2==0):
        y[i]=0
    else:
        y[i]=1
    x = x//2
    i=i+1
z = y[::-1]
print(z)
# Out:
# [1. 1. 1. 1. 1. 1. 0. 1. 0. 0. 1.]
