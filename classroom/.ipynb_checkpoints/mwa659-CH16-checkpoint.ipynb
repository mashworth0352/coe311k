# %%
import numpy as np
import matplotlib.pyplot as plt

k = 10.0
h = np.array([.01, .02, .03, .05, .1, .2, .3, .5])
x_start = 0
x_end = 10
y_0 = 1.0
v_0 = 0.0

plt.figure(figsize=(10, 6))

for j in range (h.size):
    
    x_values = np.arange(x_start, x_end + h[j], h[j])
    y_values = np.zeros(len(x_values))
    v_values = np.zeros(len(x_values))
    
    y_values[0] = y_0
    v_values[0] = v_0
    
    for i in range(1, len(x_values)):
        
        x_n = x_values[i - 1]
        y_n = y_values[i - 1]
        v_n = v_values[i - 1]    

        y_values[i] = y_n + h[j] * v_n
        v_values[i] = v_n + h[j] * (-k * y_n)

    plt.plot(x_values, y_values, label=f'Position y(x), h={h[j]}')
    plt.plot(x_values, v_values, linestyle='--', label=f'Velocity v(x), h={h[j]}')

plt.xlabel('x')
plt.ylabel('y and v')
plt.title('Solution of d²y/dx² = -ky using Euler\'s Method')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# The plots begin stable, but they start to lose stability around x=6.5. By x=9, there are large fluctuations that increase in magniture with larger step sizes. After testing different values of k (see below), it's determined that the magnitude of instability is amplified with an increase in k's value. This amplification and instability due to increasing step sizes makes Euler's method a poor candidate in solving this with larger than h=0.01 values.

# %%
import numpy as np
import matplotlib.pyplot as plt

k = 2.5
h = np.array([.01, .02, .03, .05, .1, .2, .3, .5])
x_start = 0
x_end = 10
y_0 = 1.0
v_0 = 0.0

plt.figure(figsize=(10, 10))

for j in range (h.size):
    
    x_values = np.arange(x_start, x_end + h[j], h[j])
    y_values = np.zeros(len(x_values))
    v_values = np.zeros(len(x_values))
    
    y_values[0] = y_0
    v_values[0] = v_0
    
    for i in range(1, len(x_values)):
        
        x_n = x_values[i - 1]
        y_n = y_values[i - 1]
        v_n = v_values[i - 1]    

        y_values[i] = y_n + h[j] * v_n
        v_values[i] = v_n + h[j] * (-k * y_n)

    plt.plot(x_values, y_values, label=f'Position y(x), h={h[j]}')
    plt.plot(x_values, v_values, linestyle='--', label=f'Velocity v(x), h={h[j]}')

plt.xlabel('x')
plt.ylabel('y and v')
plt.title('Solution of d²y/dx² = -ky using Euler\'s Method')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

k = 25.0
h = np.array([.01, .02, .03, .05, .1, .2, .3, .5])
x_start = 0
x_end = 10
y_0 = 1.0
v_0 = 0.0

plt.figure(figsize=(10, 10))

for j in range (h.size):
    
    x_values = np.arange(x_start, x_end + h[j], h[j])
    y_values = np.zeros(len(x_values))
    v_values = np.zeros(len(x_values))
    
    y_values[0] = y_0
    v_values[0] = v_0
    
    for i in range(1, len(x_values)):
        
        x_n = x_values[i - 1]
        y_n = y_values[i - 1]
        v_n = v_values[i - 1]    

        y_values[i] = y_n + h[j] * v_n
        v_values[i] = v_n + h[j] * (-k * y_n)

    plt.plot(x_values, y_values, label=f'Position y(x), h={h[j]}')
    plt.plot(x_values, v_values, linestyle='--', label=f'Velocity v(x), h={h[j]}')

plt.xlabel('x')
plt.ylabel('y and v')
plt.title('Solution of d²y/dx² = -ky using Euler\'s Method')
plt.legend()
plt.grid(True)
plt.show()
